# %%
import torch
from torchsummary import summary
# If there's a GPU available...
if torch.cuda.is_available():    
    # Tell PyTorch to use the GPU.    
    device = torch.device("cuda")
    print('There are %d GPU(s) available.' % torch.cuda.device_count())
    print('We will use the GPU:', torch.cuda.get_device_name(0))
# If not...
else:
    print('No GPU available, using the CPU instead.')
    device = torch.device("cpu")
# Out:
# There are 1 GPU(s) available.
# We will use the GPU: Tesla T4

# %%
import cv2
import glob
import matplotlib.pyplot as plt
from tqdm import tqdm
import numpy as np

# %% [markdown]
# # Data Loading and Preprocessing

# %%
PATH_TO_NPZ = "./drive/MyDrive/CS512_Project/data/dump/Data_All_Pix_Extreme.npz"
loaded_data = np.load(PATH_TO_NPZ)
print(loaded_data.files)
# Out:
# ['train_x', 'train_y', 'val_x', 'val_y', 'test_x', 'test_y']

# %%
train_x = loaded_data['train_x'].astype('float32')
train_y = loaded_data['train_y'].astype('float32')
val_x = loaded_data['val_x'].astype('float32')
val_y = loaded_data['val_y'].astype('float32')
test_x = loaded_data['test_x'].astype('float32')
test_y = loaded_data['test_y'].astype('float32')

print("Training set :", train_x.shape, train_y.shape)
print("Validation set :", val_x.shape, val_y.shape)
print("Test set :", test_x.shape, test_y.shape)
# Out:
# Training set : (10718, 112, 112, 3) (10718, 112, 112, 3)
# Validation set : (1191, 112, 112, 3) (1191, 112, 112, 3)
# Test set : (1324, 112, 112, 3) (1324, 112, 112, 3)

# %%
plt.subplot(321), plt.imshow(train_x[0].astype('int')), plt.title("Train Input"), plt.xticks([]), plt.yticks([])
plt.subplot(322), plt.imshow(train_y[0].astype('int')), plt.title("Train Label"), plt.xticks([]), plt.yticks([])
plt.subplot(323), plt.imshow(val_x[0].astype('int')), plt.title("Val Input"), plt.xticks([]), plt.yticks([])
plt.subplot(324), plt.imshow(val_y[0].astype('int')), plt.title("Val Label"), plt.xticks([]), plt.yticks([])
plt.subplot(325), plt.imshow(test_x[0].astype('int')), plt.title("Test Input"), plt.xticks([]), plt.yticks([])
plt.subplot(326), plt.imshow(test_y[0].astype('int')), plt.title("Test Label"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
del loaded_data

# %%
# Normalizing Images
for i in range(len(train_x)):
    train_x[i] = (train_x[i] - np.mean(train_x[i]))/255.0
    train_y[i] = (train_y[i] - np.mean(train_y[i]))/255.0

for i in range(len(val_x)):
    val_x[i] = (val_x[i] - np.mean(val_x[i]))/255.0
    val_y[i] = (val_y[i] - np.mean(val_y[i]))/255.0

for i in range(len(test_x)):
    test_x[i] = (test_x[i] - np.mean(test_x[i]))/255.0
    test_y[i] = (test_y[i] - np.mean(test_y[i]))/255.0

# %%
np.min(train_x), np.max(train_x) , np.min(train_y), np.max(train_y)
# Out:
# (-0.73754174, 0.7140656, -0.78723085, 0.7925307)

# %%
# Converting images from HxWxC format to CxHxW format
train_x = np.moveaxis(train_x, -1, 1)
train_y = np.moveaxis(train_y, -1, 1)
val_x = np.moveaxis(val_x, -1, 1)
val_y = np.moveaxis(val_y, -1, 1)
test_x = np.moveaxis(test_x, -1, 1)
test_y = np.moveaxis(test_y, -1, 1)
print("Training set :", train_x.shape, train_y.shape)
print("Validation set :", val_x.shape, val_y.shape)
print("Test set :", test_x.shape, test_y.shape)
# Out:
# Training set : (10718, 3, 112, 112) (10718, 3, 112, 112)
# Validation set : (1191, 3, 112, 112) (1191, 3, 112, 112)
# Test set : (1324, 3, 112, 112) (1324, 3, 112, 112)

# %%
import gc
gc.collect()
# Out:
# 9554

# %%
train_x = torch.tensor(train_x, dtype=torch.float)
train_y = torch.tensor(train_y, dtype=torch.float)

val_x = torch.tensor(val_x, dtype=torch.float)
val_y = torch.tensor(val_y, dtype=torch.float)

test_x = torch.tensor(test_x, dtype=torch.float)
test_y = torch.tensor(test_y, dtype=torch.float)

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

batch_size = 4

train_data = TensorDataset(train_x, train_y)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

validation_data = TensorDataset(val_x, val_y)
validation_sampler = SequentialSampler(validation_data)
validation_dataloader = DataLoader(validation_data, sampler=validation_sampler, batch_size=batch_size)

test_data = TensorDataset(test_x, test_y)
test_sampler = SequentialSampler(test_data)
test_dataloader = DataLoader(test_data, sampler=test_sampler, batch_size=batch_size)

# %% [markdown]
# # Utility Functions

# %%
def display_something(input, output, label):
    i = np.array((np.moveaxis(input.cpu().numpy(),0,-1) + 1) *127.5, dtype=np.int)
    o = np.array((np.moveaxis(output.data.cpu().numpy(),0,-1) + 1) *127.5, dtype=np.int)
    l = np.array((np.moveaxis(label.cpu().numpy(),0,-1) + 1) *127.5, dtype=np.int)
    plt.subplot(131), plt.imshow(i), plt.title("Input"), plt.xticks([]), plt.yticks([])
    plt.subplot(132), plt.imshow(o), plt.title("Output"), plt.xticks([]), plt.yticks([])
    plt.subplot(133), plt.imshow(l), plt.title("Label"), plt.xticks([]), plt.yticks([])
    plt.show()

# %%
import matplotlib.pyplot as plt
def show_progression(logs, latest_epochs=10):
    # fig, ax = plt.subplots(latest_epochs, 3, figsize=(30,30)) 
    for i in range(latest_epochs):
        i_ = np.array((np.moveaxis(logs[3*i],0,-1) + 1) *127.5, dtype=np.int)
        o = np.array((np.moveaxis(logs[3*i+1],0,-1) + 1) *127.5, dtype=np.int)
        l = np.array((np.moveaxis(logs[3*i+2],0,-1) + 1) *127.5, dtype=np.int)

        print(f"Epoch {i}")
        plt.subplot(131), plt.imshow(i_), plt.title("Input"), plt.xticks([]), plt.yticks([])
        plt.subplot(132), plt.imshow(o), plt.title("Output"), plt.xticks([]), plt.yticks([])
        plt.subplot(133), plt.imshow(l), plt.title("Label"), plt.xticks([]), plt.yticks([])
        plt.show()

# %% [markdown]
# # Model Construction

# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import Sequential, Conv2d, BatchNorm2d, ReLU, Tanh, ConvTranspose2d, Sigmoid

# %%
class Residual(nn.Module):
    def __init__(self, in_channels, out_channels,):
        super(Residual, self).__init__()

        self.conv_1 = Conv2d(in_channels, 256, kernel_size=3, padding=1)
        self.conv_2 = Conv2d(256, out_channels, kernel_size=3, padding=1)
        self.conv_1x1 = None

        self.bn_1 = BatchNorm2d(256)
        self.bn_2 = BatchNorm2d(out_channels)

        self.relu = ReLU(inplace=True)

        if in_channels != out_channels:
            self.conv_1x1 = Conv2d(in_channels, out_channels, kernel_size=1)


    def forward(self, x):
        x_ = self.relu(self.bn_1(self.conv_1(x)))
        x_ = self.bn_2(self.conv_2(x_))
        x2_ = x
        if self.conv_1x1:
            x2_ = self.conv_1x1(x)
        
        y = x_ + x2_
        return self.relu(y)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.first_conv_layers = Sequential(
            Conv2d(3, 64,  kernel_size=9, stride=1),
            BatchNorm2d(64),
            ReLU(inplace=True),
            Conv2d(64, 64, kernel_size=4, stride=2),
            BatchNorm2d(64),
            ReLU(inplace=True),
            Conv2d(64, 128, kernel_size=4, stride=2),
            BatchNorm2d(128),
            ReLU(inplace=True),
            Conv2d(128, 256, kernel_size=4, stride=2),
            BatchNorm2d(256),
            ReLU(inplace=True)
        )

        self.second_residual_blocks = Sequential(
            Residual(256, 256),
            Residual(256, 256),
            Residual(256, 256)
        )

        self.third_t_conv = Sequential(
            ConvTranspose2d(256,256, kernel_size=4, stride=2),
            BatchNorm2d(256),
            ReLU(inplace=True),
            ConvTranspose2d(256,128, kernel_size=4, stride=2),
            BatchNorm2d(128),
            ReLU(inplace=True),
            ConvTranspose2d(128,64, kernel_size=4, stride=2),
            BatchNorm2d(64),
            ReLU(inplace=True),
            ConvTranspose2d(64,3, kernel_size=11),# Comeback to this.
            Tanh()
            # ReLU(inplace=True)
            # Sigmoid()
        )

    def forward(self, x):
        x_ = self.first_conv_layers(x)
        x_ = self.second_residual_blocks(x_)
        x_ = self.third_t_conv(x_)
        # print(f"Shape of x_ = {x_.size()}")
        return x_


net = Net()

# %%
net.to(device)
summary(net, (3, 112, 112), batch_size=8)
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [8, 64, 104, 104]          15,616
#        BatchNorm2d-2          [8, 64, 104, 104]             128
#               ReLU-3          [8, 64, 104, 104]               0
#             Conv2d-4            [8, 64, 51, 51]          65,600
#        BatchNorm2d-5            [8, 64, 51, 51]             128
#               ReLU-6            [8, 64, 51, 51]               0
#             Conv2d-7           [8, 128, 24, 24]         131,200
#        BatchNorm2d-8           [8, 128, 24, 24]             256
#               ReLU-9           [8, 128, 24, 24]               0
#            Conv2d-10           [8, 256, 11, 11]         524,544
#       BatchNorm2d-11           [8, 256, 11, 11]             512
#              ReLU-12           [8, 256, 11, 11]               0
#            Conv2d-13           [8, 256, 11, 11]         590,080
#       BatchNorm2d-14           [8, 256, 11, 11]             512
#              ReLU-15           [8, 256, 11, 11]               0
#            Conv2d-16           [8, 256, 11, 11]         590,080
#       BatchNorm2d-17           [8, 256, 11, 11]             512
#              ReLU-18           [8, 256, 11, 11]               0
#          Residual-19           [8, 256, 11, 11]               0
#            Conv2d-20           [8, 256, 11, 11]         590,080
#       BatchNorm2d-21           [8, 256, 11, 11]             512
#              ReLU-22           [8, 256, 11, 11]               0
#            Conv2d-23           [8, 256, 11, 11]         590,080
#       BatchNorm2d-24           [8, 256, 11, 11]             512
#              ReLU-25           [8, 256, 11, 11]               0
#          Residual-26           [8, 256, 11, 11]               0
#            Conv2d-27           [8, 256, 11, 11]         590,080
#       BatchNorm2d-28           [8, 256, 11, 11]             512
#              ReLU-29           [8, 256, 11, 11]               0
#            Conv2d-30           [8, 256, 11, 11]         590,080
#       BatchNorm2d-31           [8, 256, 11, 11]             512
#              ReLU-32           [8, 256, 11, 11]               0
#          Residual-33           [8, 256, 11, 11]               0
#   ConvTranspose2d-34           [8, 256, 24, 24]       1,048,832
#       BatchNorm2d-35           [8, 256, 24, 24]             512
#              ReLU-36           [8, 256, 24, 24]               0
#   ConvTranspose2d-37           [8, 128, 50, 50]         524,416
#       BatchNorm2d-38           [8, 128, 50, 50]             256
#              ReLU-39           [8, 128, 50, 50]               0
#   ConvTranspose2d-40          [8, 64, 102, 102]         131,136
#       BatchNorm2d-41          [8, 64, 102, 102]             128
#              ReLU-42          [8, 64, 102, 102]               0
#   ConvTranspose2d-43           [8, 3, 112, 112]          23,235
#              Tanh-44           [8, 3, 112, 112]               0
# ================================================================
# Total params: 6,010,051
# Trainable params: 6,010,051
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 1.15
# Forward/backward pass size (MB): 428.21
# Params size (MB): 22.93
# Estimated Total Size (MB): 452.29
# ----------------------------------------------------------------

# %%
from torch.nn import MSELoss
from skimage.metrics import structural_similarity
def pixel_loss(y_true, y_pred):
    loss_fn = MSELoss()
    return loss_fn(y_true, y_pred) #/ (112*112*3)

# %%
from torch.optim import Adam
optimizer = Adam(net.parameters(), lr=1e-3)

# %% [markdown]
# # Training Phase

# %%
train_log = []
validation_log = []
loss_per_epoch = []
val_loss_per_epoch = []
val_acc_per_epoch = []

# %%
def train(epoch, fresh_run=False):
    global train_log, validation_log, loss_per_epoch, val_loss_per_epoch, val_acc_per_epoch
    if fresh_run:
        train_log = []
        validation_log = []
        loss_per_epoch = []
        val_loss_per_epoch = []
        val_acc_per_epoch = []
    for i in range(epoch):
        net.train()
        total_loss=0
        print("")
        print(f"Training @ epoch {i}")
        for step, batch in enumerate(train_dataloader):

            b_inputs = batch[0].to(device)
            b_labels = batch[1].to(device)

            net.zero_grad()

            forward_output = net(b_inputs)

            if step == 10:
                display_something(b_inputs[0], forward_output[0], b_labels[0])
                train_log.append(b_inputs[0].cpu().numpy())
                train_log.append(forward_output[0].data.cpu().numpy())
                train_log.append(b_labels[0].cpu().numpy())

            # print(forward_output[0].shape)
            # print("OP","-"*20)
            # print(forward_output[0])
            # print("IP","-"*20)
            # print(b_inputs[0])
            # print("GT","-"*20)
            # print(b_labels[0])
            

            loss = pixel_loss(b_labels, forward_output)
            total_loss += loss.item()
            # print(loss.item())
            loss.backward()

            # if net.third_t_conv[0].weight.grad != None:
            #     print("Loss", "-"*20, total_loss)
            #     print(" | After back :", net.third_t_conv[0].weight.grad, " Loss =", loss)
            optimizer.step()

        # Calculate the average loss over the training data.
        avg_train_loss = total_loss / len(train_dataloader) 
        loss_per_epoch.append(total_loss)           

        print("Total training loss: {0:.8f}".format(total_loss))



        print("")
        print(f"Running Validation for epoch {i}")
        net.eval()
        eval_accuracy, nb_eval_steps, nb_eval_examples = 0.0, 0, 0
        total_val_loss = 0.0
        once = False
        for batch in validation_dataloader:
            
            # Add batch to GPU
            batch = tuple(t.to(device) for t in batch)
            
            # Unpack the inputs from our dataloader
            b_inputs, b_labels = batch
            
            with torch.no_grad():        
                outputs = net(b_inputs)

            val_loss = pixel_loss(b_labels, outputs)
            total_val_loss += val_loss.item()
            if not once:
                display_something(b_inputs[0], outputs[0], b_labels[0])
                once = True
            
            outputs = outputs.detach().cpu().numpy()
            labels = b_labels.cpu().numpy()

            temp_eval_accuracy = 0.0
            for y1, y2 in zip(outputs, labels):
                mssim = structural_similarity(np.moveaxis(y1,0,-1).astype(np.float32), np.moveaxis(y2,0,-1).astype(np.float32), multichannel=True)
                temp_eval_accuracy += mssim
            
            # Accumulate the total accuracy.
            eval_accuracy += (temp_eval_accuracy/len(outputs))
            # Track the number of batches
            nb_eval_steps += 1
        print(f"Validation Accuracy @ epoch {i} : {eval_accuracy/nb_eval_steps}")
        print(f"Total Validation Loss @ epoch {i} : {total_val_loss}")
        val_loss_per_epoch.append(total_val_loss)
        val_acc_per_epoch.append(eval_accuracy/nb_eval_steps)
        print("-"*20,"EPOCH COMPLETE", "-"*20)

# %%
train(20, fresh_run=True)
# Out:
# Training @ epoch 0
# Total training loss: 49.14868531
#
# Running Validation for epoch 0
# Validation Accuracy @ epoch 0 : 0.6635665899485353
# Total Validation Loss @ epoch 0 : 1.8532572283875197
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 1
# Total training loss: 15.84097869
#
# Running Validation for epoch 1
# Validation Accuracy @ epoch 1 : 0.7079690923585698
# Total Validation Loss @ epoch 1 : 1.4213819557335228
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 2
# Total training loss: 14.20885372
#
# Running Validation for epoch 2
# Validation Accuracy @ epoch 2 : 0.708340004135042
# Total Validation Loss @ epoch 2 : 1.3937317098025233
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 3
# Total training loss: 12.95682040
#
# Running Validation for epoch 3
# Validation Accuracy @ epoch 3 : 0.7358120215431321
# Total Validation Loss @ epoch 3 : 1.1893104324117303
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 4
# Total training loss: 11.81457207
#
# Running Validation for epoch 4
# Validation Accuracy @ epoch 4 : 0.7366525061052244
# Total Validation Loss @ epoch 4 : 1.3916830705711618
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 5
# Total training loss: 11.11619437
#
# Running Validation for epoch 5
# Validation Accuracy @ epoch 5 : 0.7386165810145429
# Total Validation Loss @ epoch 5 : 1.497820789576508
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 6
# Total training loss: 10.58410824
#
# Running Validation for epoch 6
# Validation Accuracy @ epoch 6 : 0.7538920737691162
# Total Validation Loss @ epoch 6 : 1.4678069327492267
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 7
# Total training loss: 10.31824979
#
# Running Validation for epoch 7
# Validation Accuracy @ epoch 7 : 0.7754023791106648
# Total Validation Loss @ epoch 7 : 0.9926838045939803
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 8
# Total training loss: 9.83933947
#
# Running Validation for epoch 8
# Validation Accuracy @ epoch 8 : 0.7711574355421495
# Total Validation Loss @ epoch 8 : 1.2136158967623487
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 9
# Total training loss: 9.49749436
#
# Running Validation for epoch 9
# Validation Accuracy @ epoch 9 : 0.7752230603050471
# Total Validation Loss @ epoch 9 : 1.12823666469194
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 10
# Total training loss: 9.33553401
#
# Running Validation for epoch 10
# Validation Accuracy @ epoch 10 : 0.7795814448661664
# Total Validation Loss @ epoch 10 : 1.041533162468113
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 11
# Total training loss: 9.10902740
#
# Running Validation for epoch 11
# Validation Accuracy @ epoch 11 : 0.7682981433402779
# Total Validation Loss @ epoch 11 : 1.875329488888383
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 12
# Total training loss: 9.11063604
#
# Running Validation for epoch 12
# Validation Accuracy @ epoch 12 : 0.7769352709755177
# Total Validation Loss @ epoch 12 : 1.151411371305585
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 13
# Total training loss: 8.70827064
#
# Running Validation for epoch 13
# Validation Accuracy @ epoch 13 : 0.7809208095607751
# Total Validation Loss @ epoch 13 : 1.5088264110963792
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 14
# Total training loss: 9.21106792
#
# Running Validation for epoch 14
# Validation Accuracy @ epoch 14 : 0.7818388595940946
# Total Validation Loss @ epoch 14 : 1.5755268017528579
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 15
# Total training loss: 8.45142484
#
# Running Validation for epoch 15
# Validation Accuracy @ epoch 15 : 0.7776383806929121
# Total Validation Loss @ epoch 15 : 1.8210692012216896
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 16
# Total training loss: 8.30062100
#
# Running Validation for epoch 16
# Validation Accuracy @ epoch 16 : 0.7902278285949899
# Total Validation Loss @ epoch 16 : 1.1852434277534485
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 17
# Total training loss: 8.04868076
#
# Running Validation for epoch 17
# Validation Accuracy @ epoch 17 : 0.776577432030661
# Total Validation Loss @ epoch 17 : 1.6116262945579365
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 18
# Total training loss: 7.97817423
#
# Running Validation for epoch 18
# Validation Accuracy @ epoch 18 : 0.7765319805500699
# Total Validation Loss @ epoch 18 : 2.447088430635631
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 19
# Total training loss: 8.16372866
#
# Running Validation for epoch 19
# Validation Accuracy @ epoch 19 : 0.7746653490979082
# Total Validation Loss @ epoch 19 : 2.246477197506465
# -------------------- EPOCH COMPLETE --------------------

# %%
# Reducing lr to 1e-4
optimizer = Adam(net.parameters(), lr=1e-4)
train(5)
# Out:
# Training @ epoch 0
# Total training loss: 7.19264000
#
# Running Validation for epoch 0
# Validation Accuracy @ epoch 0 : 0.7839398000074499
# Total Validation Loss @ epoch 0 : 2.093863926245831
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 1
# Total training loss: 6.96922079
#
# Running Validation for epoch 1
# Validation Accuracy @ epoch 1 : 0.7880996829776512
# Total Validation Loss @ epoch 1 : 1.708821716834791
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 2
# Total training loss: 6.86916706
#
# Running Validation for epoch 2
# Validation Accuracy @ epoch 2 : 0.7843881149099737
# Total Validation Loss @ epoch 2 : 2.2594715076265857
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 3
# Total training loss: 6.79221042
#
# Running Validation for epoch 3
# Validation Accuracy @ epoch 3 : 0.78734864751975
# Total Validation Loss @ epoch 3 : 1.9697354534873739
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 4
# Total training loss: 6.72151446
#
# Running Validation for epoch 4
# Validation Accuracy @ epoch 4 : 0.7910338593094608
# Total Validation Loss @ epoch 4 : 1.6334256547270343
# -------------------- EPOCH COMPLETE --------------------

# %%
train(5) # Reduced BS to 4 from 8
# Out:
# Training @ epoch 0
# Total training loss: 6.68506700
#
# Running Validation for epoch 0
# Validation Accuracy @ epoch 0 : 0.7843100303757752
# Total Validation Loss @ epoch 0 : 2.317713019438088
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 1
# Total training loss: 6.62550726
#
# Running Validation for epoch 1
# Validation Accuracy @ epoch 1 : 0.7876253154739802
# Total Validation Loss @ epoch 1 : 2.0410836450755596
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 2
# Total training loss: 6.57789367
#
# Running Validation for epoch 2
# Validation Accuracy @ epoch 2 : 0.7867658224986857
# Total Validation Loss @ epoch 2 : 2.1070165750570595
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 3
# Total training loss: 6.54239971
#
# Running Validation for epoch 3
# Validation Accuracy @ epoch 3 : 0.7834485401425405
# Total Validation Loss @ epoch 3 : 2.5735077194403857
# -------------------- EPOCH COMPLETE --------------------
#
# Training @ epoch 4
# Total training loss: 6.50492059
#
# Running Validation for epoch 4
# Validation Accuracy @ epoch 4 : 0.7864765405973267
# Total Validation Loss @ epoch 4 : 2.2545038699172437
# -------------------- EPOCH COMPLETE --------------------

# %% [markdown]
# # Evaluation
# - Assessing the model's performance on train and validation sets

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(16, 8))
ax, cx = fig.subplots(1, 2)

ax.set_title("Accuracy Curves")
# ax.plot(range(1,len(fit_accuracy)+1), fit_accuracy)
ax.plot(range(1,len(val_acc_per_epoch)+1), val_acc_per_epoch)
ax.legend(['Validation Average SSIM'])

cx.set_title("Loss Curves")
cx.plot(range(1,len(loss_per_epoch)+1), loss_per_epoch[:])
cx.plot(range(1,len(val_loss_per_epoch)+1), val_loss_per_epoch[:])
cx.legend(['Train Loss', 'Validation Loss'])

plt.suptitle("Model 1 Performace Curves")

plt.show()

# %%
show_progression(train_log[:], 30)
# Out:
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Epoch 10
# Epoch 11
# Epoch 12
# Epoch 13
# Epoch 14
# Epoch 15
# Epoch 16
# Epoch 17
# Epoch 18
# Epoch 19
# Epoch 20
# Epoch 21
# Epoch 22
# Epoch 23
# Epoch 24
# Epoch 25
# Epoch 26
# Epoch 27
# Epoch 28
# Epoch 29

# %% [markdown]
# # Testing Phase
#  - Running the model on the test set

# %%
print(f"Running on Test Set")
net.eval()
eval_accuracy, nb_eval_steps, nb_eval_examples = 0.0, 0, 0
total_val_loss = 0.0
once = False
for batch in test_dataloader:
    
    # Add batch to GPU
    batch = tuple(t.to(device) for t in batch)
    
    # Unpack the inputs from our dataloader
    b_inputs, b_labels = batch
    
    with torch.no_grad():        
        outputs = net(b_inputs)

    val_loss = pixel_loss(b_labels, outputs)
    total_val_loss += val_loss.item()
    if not once:
        display_something(b_inputs[0], outputs[0], b_labels[0])
        once = True
    
    outputs = outputs.detach().cpu().numpy()
    labels = b_labels.cpu().numpy()

    temp_eval_accuracy = 0.0
    for y1, y2 in zip(outputs, labels):
        mssim = structural_similarity(np.moveaxis(y1,0,-1).astype(np.float32), np.moveaxis(y2,0,-1).astype(np.float32), multichannel=True)
        temp_eval_accuracy += mssim
    
    # Accumulate the total accuracy.
    eval_accuracy += (temp_eval_accuracy/len(outputs))
    # Track the number of batches
    nb_eval_steps += 1
print(f"Test Accuracy : {eval_accuracy/nb_eval_steps}")
print(f"Total Test Loss : {total_val_loss}")
print("-"*20,"TESTING COMPLETE", "-"*20)
# Out:
# Running on Test Set
# Test Accuracy : 0.7880821522378536
# Total Test Loss : 2.302743072155863
# -------------------- TESTING COMPLETE --------------------

# %% [markdown]
# # Save Results

# %%
torch.save(net, "./drive/MyDrive/CS512_Project/data/Final_Model_with_Results4_Pix.h5")
np.savez("./drive/MyDrive/CS512_Project/data/log_dumps4_Pix.npz",train_log=train_log, val_acc_per_epoch=val_acc_per_epoch, val_loss_per_epoch=val_loss_per_epoch, loss_per_epoch=loss_per_epoch)
